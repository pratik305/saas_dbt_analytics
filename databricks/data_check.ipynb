# %%
# %sql
SELECT current_schema();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>default</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE workspace.default.bronze_accounts;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>account_id</td><td>string</td><td>null</td></tr><tr><td>account_name</td><td>string</td><td>null</td></tr><tr><td>industry</td><td>string</td><td>null</td></tr><tr><td>country</td><td>string</td><td>null</td></tr><tr><td>signup_date</td><td>date</td><td>null</td></tr><tr><td>referral_source</td><td>string</td><td>null</td></tr><tr><td>plan_tier</td><td>string</td><td>null</td></tr><tr><td>seats</td><td>int</td><td>null</td></tr><tr><td>is_trial</td><td>boolean</td><td>null</td></tr><tr><td>churn_flag</td><td>boolean</td><td>null</td></tr><tr><td>ingestion_ts</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select account_id, count(*)
from workspace.default.bronze_accounts
group by account_id
having count(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>count(*)</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE workspace.default.bronze_subscriptions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>subscription_id</td><td>string</td><td>null</td></tr><tr><td>account_id</td><td>string</td><td>null</td></tr><tr><td>start_date</td><td>date</td><td>null</td></tr><tr><td>end_date</td><td>date</td><td>null</td></tr><tr><td>plan_tier</td><td>string</td><td>null</td></tr><tr><td>seats</td><td>int</td><td>null</td></tr><tr><td>mrr_amount</td><td>int</td><td>null</td></tr><tr><td>arr_amount</td><td>int</td><td>null</td></tr><tr><td>is_trial</td><td>boolean</td><td>null</td></tr><tr><td>upgrade_flag</td><td>boolean</td><td>null</td></tr><tr><td>downgrade_flag</td><td>boolean</td><td>null</td></tr><tr><td>churn_flag</td><td>boolean</td><td>null</td></tr><tr><td>billing_frequency</td><td>string</td><td>null</td></tr><tr><td>auto_renew_flag</td><td>boolean</td><td>null</td></tr><tr><td>ingestion_ts</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select subscription_id, count(*)
from workspace.default.bronze_subscriptions
group by subscription_id
having count(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>subscription_id</th><th>count(*)</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE workspace.default.bronze_feature_usage;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>usage_id</td><td>string</td><td>null</td></tr><tr><td>subscription_id</td><td>string</td><td>null</td></tr><tr><td>usage_date</td><td>date</td><td>null</td></tr><tr><td>feature_name</td><td>string</td><td>null</td></tr><tr><td>usage_count</td><td>int</td><td>null</td></tr><tr><td>usage_duration_secs</td><td>int</td><td>null</td></tr><tr><td>error_count</td><td>int</td><td>null</td></tr><tr><td>is_beta_feature</td><td>boolean</td><td>null</td></tr><tr><td>ingestion_ts</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select usage_id, count(*)
from workspace.default.bronze_feature_usage
group by usage_id
having count(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>usage_id</th><th>count(*)</th></tr></thead><tbody><tr><td>U-25b56c</td><td>2</td></tr><tr><td>U-662254</td><td>2</td></tr><tr><td>U-c878da</td><td>2</td></tr><tr><td>U-f42b0a</td><td>2</td></tr><tr><td>U-8128da</td><td>2</td></tr><tr><td>U-48a4aa</td><td>2</td></tr><tr><td>U-7a87ed</td><td>2</td></tr><tr><td>U-6970d1</td><td>2</td></tr><tr><td>U-d20c6d</td><td>2</td></tr><tr><td>U-ae1a6c</td><td>2</td></tr><tr><td>U-74b23f</td><td>2</td></tr><tr><td>U-649cec</td><td>2</td></tr><tr><td>U-52f4ae</td><td>2</td></tr><tr><td>U-13ce5b</td><td>2</td></tr><tr><td>U-2103bb</td><td>2</td></tr><tr><td>U-5cd3c2</td><td>2</td></tr><tr><td>U-7c6703</td><td>2</td></tr><tr><td>U-4ef9da</td><td>2</td></tr><tr><td>U-8a3738</td><td>2</td></tr><tr><td>U-0c9318</td><td>2</td></tr><tr><td>U-b0ae95</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select *
from workspace.default.bronze_feature_usage
where usage_id = 'S-02984e'
order by ingestion_ts desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>usage_id</th><th>subscription_id</th><th>usage_date</th><th>feature_name</th><th>usage_count</th><th>usage_duration_secs</th><th>error_count</th><th>is_beta_feature</th><th>ingestion_ts</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select
    subscription_id,
    usage_date,
    feature_name,
    count(*)
from workspace.default.bronze_feature_usage
group by 1,2,3
having count(*) > 1
limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>subscription_id</th><th>usage_date</th><th>feature_name</th><th>count(*)</th></tr></thead><tbody><tr><td>S-02984e</td><td>2023-02-21</td><td>feature_13</td><td>2</td></tr><tr><td>S-fedcd9</td><td>2023-10-10</td><td>feature_27</td><td>2</td></tr><tr><td>S-efdeae</td><td>2024-07-21</td><td>feature_12</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select *
from workspace.default.bronze_feature_usage
where subscription_id = 'S-efdeae'
  and usage_date = '2024-07-21'
  and feature_name = 'feature_12'
order by ingestion_ts;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>usage_id</th><th>subscription_id</th><th>usage_date</th><th>feature_name</th><th>usage_count</th><th>usage_duration_secs</th><th>error_count</th><th>is_beta_feature</th><th>ingestion_ts</th></tr></thead><tbody><tr><td>U-50502e</td><td>S-efdeae</td><td>2024-07-21</td><td>feature_12</td><td>4</td><td>1796</td><td>0</td><td>false</td><td>2026-02-11T15:13:12.098Z</td></tr><tr><td>U-e90b1a</td><td>S-efdeae</td><td>2024-07-21</td><td>feature_12</td><td>8</td><td>3920</td><td>0</td><td>false</td><td>2026-02-11T15:13:12.098Z</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE workspace.default.bronze_churn_events;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>churn_event_id</td><td>string</td><td>null</td></tr><tr><td>account_id</td><td>string</td><td>null</td></tr><tr><td>churn_date</td><td>date</td><td>null</td></tr><tr><td>reason_code</td><td>string</td><td>null</td></tr><tr><td>refund_amount_usd</td><td>double</td><td>null</td></tr><tr><td>preceding_upgrade_flag</td><td>boolean</td><td>null</td></tr><tr><td>preceding_downgrade_flag</td><td>boolean</td><td>null</td></tr><tr><td>is_reactivation</td><td>boolean</td><td>null</td></tr><tr><td>feedback_text</td><td>string</td><td>null</td></tr><tr><td>ingestion_ts</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select churn_event_id, count(*)
from workspace.default.bronze_churn_events
group by churn_event_id
having count(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>churn_event_id</th><th>count(*)</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE workspace.default.bronze_support_tickets;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>ticket_id</td><td>string</td><td>null</td></tr><tr><td>account_id</td><td>string</td><td>null</td></tr><tr><td>submitted_at</td><td>date</td><td>null</td></tr><tr><td>closed_at</td><td>timestamp</td><td>null</td></tr><tr><td>resolution_time_hours</td><td>double</td><td>null</td></tr><tr><td>priority</td><td>string</td><td>null</td></tr><tr><td>first_response_time_minutes</td><td>int</td><td>null</td></tr><tr><td>satisfaction_score</td><td>double</td><td>null</td></tr><tr><td>escalation_flag</td><td>boolean</td><td>null</td></tr><tr><td>ingestion_ts</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select ticket_id, count(*)
from workspace.default.bronze_support_tickets
group by ticket_id
having count(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ticket_id</th><th>count(*)</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE workspace.analytics.stg_support_tickets;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>account_id</td><td>string</td><td>null</td></tr><tr><td>submitted_at</td><td>date</td><td>null</td></tr><tr><td>closed_at</td><td>timestamp</td><td>null</td></tr><tr><td>resolution_time_hours</td><td>double</td><td>null</td></tr><tr><td>priority</td><td>string</td><td>null</td></tr><tr><td>first_response_time_minutes</td><td>int</td><td>null</td></tr><tr><td>satisfaction_score</td><td>double</td><td>null</td></tr><tr><td>escalation_flag</td><td>boolean</td><td>null</td></tr><tr><td>ingestion_ts</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select account_id, count(*)
from workspace.analytics.stg_subscriptions
group by account_id
having count(*) > 1
limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>account_id</th><th>count(*)</th></tr></thead><tbody><tr><td>A-3c1a3f</td><td>12</td></tr><tr><td>A-9b9fe9</td><td>12</td></tr><tr><td>A-659280</td><td>12</td></tr><tr><td>A-e7a1e2</td><td>12</td></tr><tr><td>A-ba6516</td><td>13</td></tr><tr><td>A-fa2041</td><td>12</td></tr><tr><td>A-417d2f</td><td>16</td></tr><tr><td>A-5f2961</td><td>7</td></tr><tr><td>A-cc8c8f</td><td>7</td></tr><tr><td>A-80eeb6</td><td>16</td></tr></tbody></table></div>

# %%
# %sql
select
    subscription_id,
    count(*)
from workspace.analytics.stg_subscriptions
group by subscription_id
having count(*) > 1
limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>subscription_id</th><th>count(*)</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select count(*) 
from workspace.analytics.stg_subscriptions
where end_date is null;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>4514</td></tr></tbody></table></div>
